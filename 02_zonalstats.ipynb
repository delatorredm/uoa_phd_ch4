# %%
# %matplotlib inline

from pysal.model import spreg
from pysal.lib import weights
from pysal.explore import esda
from scipy import stats
import statsmodels.formula.api as sm
import numpy
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
import seaborn
import rioxarray as rxr
import rasterstats as rs
import rasterio

# %%
eviPath = '/Users/delatorredm/OneDrive - The University of Auckland/Ch4_Climate_Impacts/ver03/eviTS_2017.tiff'
evi = rxr.open_rasterio(eviPath, masked=True, name='evi').squeeze()
im_evi = evi.plot.imshow()

# %%
bdryPath = geopandas.read_file('/Users/delatorredm/OneDrive - The University of Auckland/Ch4_Climate_Impacts/irr_ws_intersect_admbnda.gpkg')
bdryPath.head()
# Out:
#             Class        ADM3_EN  \
# 0  Irrigated Rice  Barotac Viejo
# 1  Irrigated Rice  Barotac Viejo
# 2  Irrigated Rice  Barotac Viejo
# 3  Irrigated Rice  Barotac Viejo
# 4  Irrigated Rice  Barotac Viejo
#
#                                             geometry
# 0  MULTIPOLYGON (((122.86312 11.10470, 122.86312 ...
# 1  MULTIPOLYGON (((122.86330 11.10443, 122.86330 ...
# 2  MULTIPOLYGON (((122.86195 11.10417, 122.86195 ...
# 3  MULTIPOLYGON (((122.86617 11.10417, 122.86617 ...
# 4  MULTIPOLYGON (((122.86186 11.10399, 122.86186 ...

# %%
eviStats = rs.zonal_stats(bdryPath, eviPath, band = 1, stats = 'mean') #WS or DS
# Out:
# /Users/delatorredm/miniconda3/envs/ee/lib/python3.8/site-packages/rasterstats/io.py:301: UserWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn("Setting nodata to -999; specify nodata explicitly")

# %%
eviStats
# Out:
# [{'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
#  {'mean': None},
# ...
